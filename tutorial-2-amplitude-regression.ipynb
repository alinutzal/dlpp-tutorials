# %% [markdown]
# # Amplitude regression

# %% [markdown]
# In the lectures you've covered multi-variate analyses, fits and interpolations, and the basics of neural networks.  Here we'll put this into practice by building a neural network in pytorch to perform a regression task on the LHC amplitude for the production of two photons and a gluon in a gluon-gluon collision.

# %% [markdown]
# We want to train a network to predict the amplitude for the process $gg\rightarrow\gamma\gamma g$.  So the amplitude depends on the 4-momentum of 5 particles: 2 incoming gluons, 2 outgoing photons, and one outgoing gluon.
#
# The incoming gluons will have no transverse momentum, but their total momentum along the beam pipe is not necessarily zero.
#
# The network we will train is a simple fully connected dense network.  This means that the input and output can only be vectors of real numbers.  We want to input the kinematic information on the particles to the network, and train the network to output the corresponding amplitude.  So we need to think about how we input our kinematic 4-vectors to the network, this generally depends on the network architecture we are using.

# %% [markdown]
# #### Outline / tasks:
#  - Imports \& plotting set-up
#  - Loading the data
#  - Visualising the data
#      - visualise some of the kinematics of the process (transverse momentum of photons/gluons, MET)
#      - histogram the amplitudes
#  - Preprocessing the data
#      - neural networks like $\mathcal{O}(1)$ numbers
#      - how should we preprocess the data?
#  - Datasets and dataloaders
#      - details are in the pytorch docs
#  - Building the neural network
#      - construct a cimple neural network with 2 hidden layers with some number of nodes, it's up to you
#      - tip: use linear layers followed by relu activations
#      - all the relevant details are in the pytorch docs
#  - Optimising (training) the neural network
#      - create a function to train the network for a single epoch
#      - create functions to compute the test and validation loss at the end of an epoch
#      - define a loss function (tip: MSE is a good choice)
#      - define an optimizer (tip: Adam is a good choice)
#      - train the network for some number of epochs
#  - Plot the train and validation losses as a function of the epochs
#      - to check the the network is training we should plot the train and validation losses as a function of the epochs
#  - Study the results
#      - beyond the losses, how can we check that our network is making sensible predictions?
#  - Can you think of ways to improve your network or your training?  List them!
#
# Most practical pytorch skills you need for this work is covered in the basics tutorial at https://pytorch.org/tutorials/beginner/basics/intro.html.

# %% [markdown]
# ### Imports

# %%
import os
import sys
import random
import time
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn

# %% [markdown]
# #### Plotting set-up

# %%
from matplotlib import pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")
from matplotlib.lines import Line2D
from matplotlib.font_manager import FontProperties
import matplotlib.colors as mcolors
import colorsys

labelfont = FontProperties()
labelfont.set_family('serif')
labelfont.set_name('Times New Roman')
labelfont.set_size(14)

axislabelfont = FontProperties()
axislabelfont.set_family('serif')
axislabelfont.set_name('Times New Roman')
axislabelfont.set_size(22)

tickfont = FontProperties()
tickfont.set_family('serif')
tickfont.set_name('Times New Roman')
tickfont.set_size(16)

axisfontsize = 16
labelfontsize = 16

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["mathtext.default"] = "rm"
plt.rcParams['text.usetex'] = True

# %% [markdown]
# ## Loading the data

# %%
trn_dat = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/trn_dat.npy" )
trn_amp = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/trn_amp.npy" )

val_dat = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/val_dat.npy" )
val_amp = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/val_amp.npy" )

tst_dat = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/tst_dat.npy" )
tst_amp = np.load( "/fs/scratch/PLS0144/alina/particle/dlpp-data/tutorial-2-data/tst_amp.npy" )

# %%
print( f"train data shape: {trn_dat.shape}" )
print( f"train amp  shape: {trn_amp.shape}" )
print( f"test  data shape: {tst_dat.shape}" )
print( f"test  amp  shape: {tst_amp.shape}" )
print( f"val   data shape: {val_dat.shape}" )
print( f"val   amp  shape: {val_amp.shape}" )
# Out:
# train data shape: (30000, 5, 4)
# train amp  shape: (30000,)
# test  data shape: (30000, 5, 4)
# test  amp  shape: (30000,)
# val   data shape: (30000, 5, 4)
# val   amp  shape: (30000,)

# %% [markdown]
# The data is organised as follows:
#  - the shape corresponds to ( number of events, number of particles, 4-momentum )
#  - the particles are arranged as follows
#      - the first two entries are the two incoming gluons
#      - the next two particles are the outgoing photons
#      - the last particle is the outgoing gluon
#  - the incoming gluons and incoming photons are arranged by transverse memontum $p_T$

# %% [markdown]
# Why is the ordering important?

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# Below we will make some kinematic plots of the events in the training sample.  Note however that these are not the physical distributions we would measure at the LHC!  In our training data each of these events is associated with an amplitude, which tells us the probability that the event will be produced in the gluon-gluon interaction.  So to get the physical distributions these events would need to be 'weighted' by their amplitude.  However, right now we just want to visualise our training dataset to see what preprocessing we should do.

# %%
def get_init_pz( ev ):
    return ev[0][3] + ev[1][3]

def get_mass( fv ):
    msq = np.round( fv[0]**2 - fv[1]**2 - fv[2]**2 - fv[3]**2 , 5 )
    if msq>0:
        return np.sqrt( msq )
    elif msq<0:
        raise Exception( "mass squared is less than zero" ) 
    else:
        return 0
    
def get_pt( fv ):
    ptsq = np.round( fv[1]**2 + fv[2]**2 , 5 )
    if ptsq>0:
        return np.sqrt( ptsq )
    elif ptsq<0:
        raise Exception( "$p_T$ squared is less than zero" ) 
    else:
        return 0
    
def get_met( ev ):
    return np.abs( np.sum( [ fv[1]+fv[2] for fv in ev ] ) )

# %% [markdown]
# Plotting the initial $p_z$ of the events in the training sample.

# %%
trn_dat_init_pz = []
for ev in trn_dat:
    trn_dat_init_pz.append( get_init_pz( ev ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_init_pz, histtype='stepfilled', fill=None )

axs.set_xlabel( "initial $p_z$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# We can plot a histogram of the amplitudes for the training data.

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_amp, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )
axs.set_xscale( 'log' )

axs.set_xlabel( "train amplitudes", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The amplitudes span about 4 orders of magnitude...

# %% [markdown]
# Plotting the leading photon $p_T$.

# %%
trn_dat_leading_photon_pt = []
for ev in trn_dat:
    trn_dat_leading_photon_pt.append( get_pt( ev[2] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_leading_photon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading photon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# Plot the final state gluon $p_T$.

# %%
trn_dat_gluon_pt = []
for ev in trn_dat:
    trn_dat_gluon_pt.append( get_pt( ev[4] ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_gluon_pt, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "leading gluon $p_T$ (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The mean final state gluon $p_T$ in GeV is:

# %%
np.mean( trn_dat_gluon_pt )
# Out:
# 49.698076969543024

# %% [markdown]
# Plotting the missing transverse energy (MET) for each event.

# %%
trn_dat_met = []
for ev in trn_dat:
    trn_dat_met.append( get_met( ev ) )

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_dat_met, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "MET (GeV)", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# As expected, this is zero for all events (except one, oddly).  We expect this because the incoming gluons have no $p_T$.
#
# Let's see where this single high MET event arises...

# %%
np.where( np.array(trn_dat_met) > 300 )
# Out:
# (array([12127]),)

# %%
trn_dat[12127]
# Out:
# array([[ 360.37961003,   96.31550214,  192.63100427,  288.94650641],
#        [ 693.71294336, -185.40258277, -370.80516555, -556.20774832],
#        [ 506.22226952, -340.95585115, -332.00806946, -172.57095798],
#        [ 360.29766015,  277.8398014 ,  214.67663535,   80.82939381],
#        [ 187.57262372,  -25.97103088,  -60.84272717, -175.51967775]])

# %% [markdown]
# The incoming gluons are not along the beampipe.  This is a bug in the dataset. 1/30k is not such a big deal.

# %%
[ get_mass( x ) for x in trn_dat[12127] ]
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# At least the constituents are massless..

# %% [markdown]
# ## Preprocessing the data

# %% [markdown]
# We will be using a dense network, so the data needs to be in vector format.  We will collapse the data for each event to a single vector of dimension $5\times4=20$.  The fact that the data is ordered here is important.  To predict the amplitude given the kinematics, the network needs to know which entries correspond to which particles in the process.

# %%
nev = trn_dat.shape[0]
trn_datf = np.reshape( trn_dat, (nev,-1) )
val_datf = np.reshape( val_dat, (nev,-1) )
tst_datf = np.reshape( tst_dat, (nev,-1) )

# %% [markdown]
# Check the shape:

# %%
trn_datf.shape
# Out:
# (30000, 20)

# %% [markdown]
# There are further preprocessing steps we can take.  For example, the inputs are numerically very large $\mathcal{O}(100)$ and span a large range.  So we could re-scale the inputs by a constant number, or even take the logarithm of the inputs.
#
# For now, we'll just re-scale by a constant number, the average final state gluon $p_T$, assuming that this is a natural scale for the problem.  And we should be careful to preprocess the train, validation, and test data in the exact same way.

# %%
gpt = np.mean( trn_dat_gluon_pt )
trn_datf = trn_datf / gpt
val_datf = val_datf / gpt
tst_datf = tst_datf / gpt

# %% [markdown]
# Now convert them to pytorch tensors.

# %%
trn_datfp = torch.Tensor( trn_datf )
val_datfp = torch.Tensor( val_datf )
tst_datfp = torch.Tensor( tst_datf )

# %% [markdown]
# We should also preprocess the amplitude data.  As we seen in a plot above, the amplitudes span about 4 orders of magnitude.  This could be difficult for the network to interpolate.  We can aleviate the problem with preprocessing, taking the logarithm of the amplitudes.

# %%
trn_ampl = np.log( trn_amp )
val_ampl = np.log( val_amp )
tst_ampl = np.log( tst_amp )

# %%
trn_amplp = torch.Tensor( trn_ampl )
val_amplp = torch.Tensor( val_ampl )
tst_amplp = torch.Tensor( tst_ampl )

# %%
torch.mean( val_amplp )
# Out:
# tensor(-14.7285)

# %% [markdown]
# The new distribution looks nicer:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

axs.hist( trn_ampl, histtype='stepfilled', fill=None )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Datasets and dataloaders

# %% [markdown]
# First define a class for the datasets.

# %%
class amp_dataset( Dataset ):
    
    def __init__( self, data, amp ):
        self.data = data
        self.amp = amp

    def __len__(self):
        return len(self.amp)

    def __getitem__(self, idx):
        return self.data[idx], self.amp[idx]

# %% [markdown]
# Then initialise them with the data and amplitudes.  We use unsqueeze here so that the shape of the amplitudes matches the shape output from the neural network.

# %%
trn_dataset = amp_dataset( trn_datfp, trn_amplp.unsqueeze(-1) )
val_dataset = amp_dataset( val_datfp, val_amplp.unsqueeze(-1) )
tst_dataset = amp_dataset( tst_datfp, tst_amplp.unsqueeze(-1) )

# %% [markdown]
# Now we can define a dataloader for each of these datasets.

# %%
trn_dataloader = DataLoader( trn_dataset, batch_size=64, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=64, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=64, shuffle=True )

# %% [markdown]
# We can test our dataloader.

# %%
next( iter( trn_dataloader ) )
# Out:
# [tensor([[ 2.1620e+00,  0.0000e+00,  0.0000e+00,  ..., -7.1327e-01,
#            5.9109e-01,  5.6937e-02],
#          [ 3.4595e+00,  0.0000e+00,  0.0000e+00,  ..., -7.0603e-01,
#           -9.6572e-01,  1.2985e+00],
#          [ 1.8645e+00,  0.0000e+00,  0.0000e+00,  ..., -6.2210e-01,
#            6.9833e-01,  1.7173e-01],
#          ...,
#          [ 2.5336e+00,  0.0000e+00,  0.0000e+00,  ...,  2.6772e-03,
#            5.4936e-01,  1.1868e-01],
#          [ 3.0810e+00,  0.0000e+00,  0.0000e+00,  ...,  1.0995e+00,
#            1.1111e-01,  6.4604e-01],
#          [ 4.3302e+00,  0.0000e+00,  0.0000e+00,  ..., -4.7632e-01,
#           -9.9948e-02,  8.3524e-01]]),
#  tensor([[-15.4621],
#          [-16.0017],
#          [-15.6511],
#          [-15.1988],
#          [-14.9139],
#          [-13.2643],
#          [-14.3757],
#          [-13.8745],
#          [-14.8751],
#          [-14.0065],
#          [-15.1235],
#          [-14.6744],
#          [-13.6175],
#          [-15.8531],
#          [-15.8505],
#          [-15.3272],
#          [-15.1177],
#          [-14.8904],
#          [-14.5775],
#          [-13.1336],
#          [-13.9808],
#          [-15.4846],
#          [-14.9598],
#          [-14.3187],
#          [-14.4936],
#          [-15.3032],
#          [-14.2958],
#          [-15.6821],
#          [-12.8768],
#          [-14.7239],
#          [-14.2742],
#          [-15.4562],
#          [-14.1186],
#          [-14.6366],
#          [-13.9593],
#          [-14.3676],
#          [-14.2462],
#          [-13.9127],
#          [-14.8638],
#          [-15.2887],
#          [-14.4240],
#          [-13.9472],
#          [-14.3831],
#          [-16.1170],
#          [-15.7989],
#          [-14.8283],
#          [-15.5494],
#          [-14.1780],
#          [-15.4069],
#          [-15.4357],
#          [-14.2153],
#          [-14.6017],
#          [-14.3198],
#          [-14.2940],
#          [-13.4813],
#          [-12.7640],
#          [-13.5050],
#          [-12.6299],
#          [-14.9724],
#          [-15.2650],
#          [-14.1073],
#          [-14.4332],
#          [-15.3857],
#          [-14.0948]])]

# %% [markdown]
# And we can check that the shape for the kinematic data and amplitudes come out correct.

# %%
next( iter( trn_dataloader ) )[0].shape
# Out:
# torch.Size([64, 20])

# %%
next( iter( trn_dataloader ) )[1].shape
# Out:
# torch.Size([64, 1])

# %% [markdown]
# ## Building the neural network

# %% [markdown]
# We'll build a simple network with one input and one output layer, and two hidden layers.  We define the dimensions of these layers below.

# %%
ipt_dim = 20
opt_dim = 1
hdn_dim = 30

# %% [markdown]
# Now we build a very simple class for our neural network, which we call amp_net.

# %%
class amp_net( nn.Module ):
    
    # default hdn_dim is 30, but can be changed upon initialisation
    def __init__( self, hdn_dim=30 ):
        
        super( amp_net, self ).__init__()
        
        self.linear_relu_stack = nn.Sequential(
            nn.Linear( ipt_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, hdn_dim ),
            nn.ReLU(),
            nn.Linear( hdn_dim, opt_dim ),
        )

    def forward( self, x ):
        out = self.linear_relu_stack( x )
        return out

# %% [markdown]
# Check if we have a GPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# Initialise the neural network and send to the GPU if we have one.  We can also print the model to see what layers it has.

# %%
model = amp_net( hdn_dim=hdn_dim ).to(device)
print(model)
# Out:
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# Now we can test it briefly by throwing some random numbers into it.

# %%
X = torch.rand(40, 20, device=device)
model( X )
# Out:
# tensor([[0.0445],
#         [0.0365],
#         [0.0473],
#         [0.0546],
#         [0.0473],
#         [0.0636],
#         [0.0631],
#         [0.0516],
#         [0.0554],
#         [0.0546],
#         [0.0286],
#         [0.0128],
#         [0.0643],
#         [0.0477],
#         [0.0698],
#         [0.0429],
#         [0.0295],
#         [0.0728],
#         [0.0566],
#         [0.0781],
#         [0.0416],
#         [0.0624],
#         [0.0310],
#         [0.0487],
#         [0.0558],
#         [0.0478],
#         [0.0521],
#         [0.0483],
#         [0.0340],
#         [0.0474],
#         [0.0450],
#         [0.0184],
#         [0.0344],
#         [0.0347],
#         [0.0527],
#         [0.0714],
#         [0.0499],
#         [0.0892],
#         [0.0699],
#         [0.0566]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
model( X ).shape
# Out:
# torch.Size([40, 1])

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# Looks like it's working.

# %% [markdown]
# ## Optimising (training) the neural network

# %% [markdown]
# We need to decide what function we want the neural network to optimise, i.e. the loss function.  There are a number of choices to decide from, the key point is that the loss function should be minimised when the neural network correctly predicts the amplitude given the kinematical information on the event.  For this we'll use the MSE, the mean squared error.
#
# $\text{MSE} = ( \text{pred_amp} - \text{true_amp} )^2 $

# %%
loss_fn = nn.MSELoss()

# %% [markdown]
# PyTorch will compute gradients of this loss function with respect to the trainable parameters of the network.  The network is optimised by updating the parameters using the gradients.  The exact scheme to do this is defined by our choice of optimiser.  A standard choice is the Adam optimiser, which we will use here with it's default hyper-parameters.
#
# You can read more about this optimiser here:
#  - https://pytorch.org/docs/stable/generated/torch.optim.Adam.html
#  - https://arxiv.org/abs/1412.6980

# %%
learning_rate = 1e-3
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )

# %% [markdown]
# We've already set the batch size when defining the dataloaders.  Below we set the number of epochs, i.e. the number of times we will iterate through the training data to optimise the network.  This means that the total number of updates to the network parameters will be $\simeq\text{size of dataset}\times \text{epochs} / \text{batch size}$.

# %% [markdown]
# Now we can write a training loop for a single epoch.

# %%
def train_epoch( dataloader, model, loss_fn, optimizer ):
    
    size = len( dataloader.dataset )
    
    for batch, (X, y) in enumerate(dataloader):

        # pass data through network
        pred = model(X.to(device))
        
        # compute loss
        loss = loss_fn( pred, y.to(device) )

        # reset gradients in optimizer
        optimizer.zero_grad()
        
        # compute gradients
        loss.backward()
        
        # update weights with optimizer
        optimizer.step()
        
        # print the training loss every 100 updates
        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print( f"current batch loss: {loss:>7f}  [{current:>5d}/{size:>5d}]" )

# %% [markdown]
# To monitor the performance of the network on the regression task we want to calculate the loss of both the training data and the validation data on the same network, so we have the following functions:

# %%
def val_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    vl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X.to(device) )
            vl += loss_fn( pred, y.to(device) ).item()

    vl /= num_batches
    print( f"avg val loss per batch: {vl:>8f}" )
    
    return vl

def trn_pass( dataloader, model, loss_fn ):
    
    size = len( dataloader.dataset )
    num_batches = len( dataloader )
    tl = 0.0

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            pred = model( X.to(device) )
            tl += loss_fn( pred, y.to(device) ).item()

    tl /= num_batches
    print( f"avg trn loss per batch: {tl:>8f}" )
    
    return tl

# %% [markdown]
# Now we can train the model!

# %%
# a useful function to present things clearer
def seperator():
    print( "-----------------------------------------------" )

# reset some parameters
batch_size = 128
trn_dataloader = DataLoader( trn_dataset, batch_size=batch_size, shuffle=True )
val_dataloader = DataLoader( val_dataset, batch_size=batch_size, shuffle=True )
tst_dataloader = DataLoader( tst_dataset, batch_size=batch_size, shuffle=True )
epochs = 150

# re-initialise the model and the optimizer
hdn_dim = 50
model = amp_net( hdn_dim=hdn_dim ).to(device)
learning_rate = 5e-4
optimizer = torch.optim.Adam( model.parameters(), lr=learning_rate )
seperator()
print( "model architecture ")
seperator()
print( model )

# track train and val losses
trn_losses = []
val_losses = []

for t in range(epochs):
    seperator()
    print( f"Epoch {t+1}" )
    seperator()
    train_epoch( trn_dataloader, model, loss_fn, optimizer )
    seperator()
    trn_loss = trn_pass( trn_dataloader, model, loss_fn )
    trn_losses.append( trn_loss )
    seperator()
    val_loss = val_pass( val_dataloader, model, loss_fn )
    val_losses.append( val_loss )
    seperator()
    print( "|" )
    
print("Done!")
# Out:
# -----------------------------------------------
# model architecture
# -----------------------------------------------
# amp_net(
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=20, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=50, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
# -----------------------------------------------
# Epoch 1
# -----------------------------------------------
# current batch loss: 209.076813  [    0/30000]
# current batch loss: 41.412949  [12800/30000]
# current batch loss: 32.789368  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 32.622193
# -----------------------------------------------
# avg val loss per batch: 32.682247
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 2
# -----------------------------------------------
# current batch loss: 35.276939  [    0/30000]
# current batch loss: 26.544838  [12800/30000]
# current batch loss: 21.041063  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 14.652878
# -----------------------------------------------
# avg val loss per batch: 14.963281
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 3
# -----------------------------------------------
# current batch loss: 14.739312  [    0/30000]
# current batch loss: 5.229065  [12800/30000]
# current batch loss: 1.824410  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 1.193808
# -----------------------------------------------
# avg val loss per batch: 1.261752
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 4
# -----------------------------------------------
# current batch loss: 0.900710  [    0/30000]
# current batch loss: 0.809422  [12800/30000]
# current batch loss: 0.599268  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.539700
# -----------------------------------------------
# avg val loss per batch: 0.543990
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 5
# -----------------------------------------------
# current batch loss: 0.514382  [    0/30000]
# current batch loss: 0.784177  [12800/30000]
# current batch loss: 0.349473  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.490101
# -----------------------------------------------
# avg val loss per batch: 0.490195
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 6
# -----------------------------------------------
# current batch loss: 0.388883  [    0/30000]
# current batch loss: 0.473098  [12800/30000]
# current batch loss: 0.420171  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.432103
# -----------------------------------------------
# avg val loss per batch: 0.433976
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 7
# -----------------------------------------------
# current batch loss: 0.402245  [    0/30000]
# current batch loss: 0.427382  [12800/30000]
# current batch loss: 0.535383  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.417668
# -----------------------------------------------
# avg val loss per batch: 0.417777
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 8
# -----------------------------------------------
# current batch loss: 0.443451  [    0/30000]
# current batch loss: 0.491164  [12800/30000]
# current batch loss: 0.389166  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.441481
# -----------------------------------------------
# avg val loss per batch: 0.443546
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 9
# -----------------------------------------------
# current batch loss: 0.452854  [    0/30000]
# current batch loss: 0.370952  [12800/30000]
# current batch loss: 0.385586  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.389408
# -----------------------------------------------
# avg val loss per batch: 0.389210
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 10
# -----------------------------------------------
# current batch loss: 0.401655  [    0/30000]
# current batch loss: 0.388312  [12800/30000]
# current batch loss: 0.353977  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.381297
# -----------------------------------------------
# avg val loss per batch: 0.380199
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 11
# -----------------------------------------------
# current batch loss: 0.372960  [    0/30000]
# current batch loss: 0.253756  [12800/30000]
# current batch loss: 0.323527  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.379870
# -----------------------------------------------
# avg val loss per batch: 0.378135
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 12
# -----------------------------------------------
# current batch loss: 0.297972  [    0/30000]
# current batch loss: 0.310525  [12800/30000]
# current batch loss: 0.299354  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.365899
# -----------------------------------------------
# avg val loss per batch: 0.364520
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 13
# -----------------------------------------------
# current batch loss: 0.318339  [    0/30000]
# current batch loss: 0.398020  [12800/30000]
# current batch loss: 0.360602  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.362943
# -----------------------------------------------
# avg val loss per batch: 0.362922
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 14
# -----------------------------------------------
# current batch loss: 0.288586  [    0/30000]
# current batch loss: 0.386622  [12800/30000]
# current batch loss: 0.443133  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.352001
# -----------------------------------------------
# avg val loss per batch: 0.352304
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 15
# -----------------------------------------------
# current batch loss: 0.330634  [    0/30000]
# current batch loss: 0.249304  [12800/30000]
# current batch loss: 0.424024  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.354595
# -----------------------------------------------
# avg val loss per batch: 0.354945
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 16
# -----------------------------------------------
# current batch loss: 0.349325  [    0/30000]
# current batch loss: 0.343972  [12800/30000]
# current batch loss: 0.315767  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.378628
# -----------------------------------------------
# avg val loss per batch: 0.379719
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 17
# -----------------------------------------------
# current batch loss: 0.383517  [    0/30000]
# current batch loss: 0.332923  [12800/30000]
# current batch loss: 0.207807  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.338986
# -----------------------------------------------
# avg val loss per batch: 0.338975
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 18
# -----------------------------------------------
# current batch loss: 0.397774  [    0/30000]
# current batch loss: 0.348088  [12800/30000]
# current batch loss: 0.247645  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.319457
# -----------------------------------------------
# avg val loss per batch: 0.317989
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 19
# -----------------------------------------------
# current batch loss: 0.254761  [    0/30000]
# current batch loss: 0.271040  [12800/30000]
# current batch loss: 0.349460  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.318307
# -----------------------------------------------
# avg val loss per batch: 0.315948
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 20
# -----------------------------------------------
# current batch loss: 0.234481  [    0/30000]
# current batch loss: 0.472963  [12800/30000]
# current batch loss: 0.321764  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.297816
# -----------------------------------------------
# avg val loss per batch: 0.294894
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 21
# -----------------------------------------------
# current batch loss: 0.304553  [    0/30000]
# current batch loss: 0.272356  [12800/30000]
# current batch loss: 0.297754  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.290066
# -----------------------------------------------
# avg val loss per batch: 0.290778
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 22
# -----------------------------------------------
# current batch loss: 0.274311  [    0/30000]
# current batch loss: 0.277566  [12800/30000]
# current batch loss: 0.349906  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.293082
# -----------------------------------------------
# avg val loss per batch: 0.292798
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 23
# -----------------------------------------------
# current batch loss: 0.264374  [    0/30000]
# current batch loss: 0.388369  [12800/30000]
# current batch loss: 0.231771  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.294010
# -----------------------------------------------
# avg val loss per batch: 0.293786
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 24
# -----------------------------------------------
# current batch loss: 0.277898  [    0/30000]
# current batch loss: 0.272204  [12800/30000]
# current batch loss: 0.347592  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.283715
# -----------------------------------------------
# avg val loss per batch: 0.285439
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 25
# -----------------------------------------------
# current batch loss: 0.262676  [    0/30000]
# current batch loss: 0.222239  [12800/30000]
# current batch loss: 0.259055  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.259605
# -----------------------------------------------
# avg val loss per batch: 0.260784
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 26
# -----------------------------------------------
# current batch loss: 0.241756  [    0/30000]
# current batch loss: 0.254562  [12800/30000]
# current batch loss: 0.301167  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.258366
# -----------------------------------------------
# avg val loss per batch: 0.260895
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 27
# -----------------------------------------------
# current batch loss: 0.223862  [    0/30000]
# current batch loss: 0.312866  [12800/30000]
# current batch loss: 0.213517  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.259654
# -----------------------------------------------
# avg val loss per batch: 0.259127
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 28
# -----------------------------------------------
# current batch loss: 0.253945  [    0/30000]
# current batch loss: 0.201451  [12800/30000]
# current batch loss: 0.239821  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.245220
# -----------------------------------------------
# avg val loss per batch: 0.247121
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 29
# -----------------------------------------------
# current batch loss: 0.220865  [    0/30000]
# current batch loss: 0.220510  [12800/30000]
# current batch loss: 0.221274  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.221636
# -----------------------------------------------
# avg val loss per batch: 0.224630
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 30
# -----------------------------------------------
# current batch loss: 0.205105  [    0/30000]
# current batch loss: 0.219713  [12800/30000]
# current batch loss: 0.308166  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.211261
# -----------------------------------------------
# avg val loss per batch: 0.214233
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 31
# -----------------------------------------------
# current batch loss: 0.165102  [    0/30000]
# current batch loss: 0.162321  [12800/30000]
# current batch loss: 0.220096  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.211694
# -----------------------------------------------
# avg val loss per batch: 0.214299
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 32
# -----------------------------------------------
# current batch loss: 0.181145  [    0/30000]
# current batch loss: 0.166297  [12800/30000]
# current batch loss: 0.177785  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.200595
# -----------------------------------------------
# avg val loss per batch: 0.206232
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 33
# -----------------------------------------------
# current batch loss: 0.152688  [    0/30000]
# current batch loss: 0.153698  [12800/30000]
# current batch loss: 0.174000  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.188103
# -----------------------------------------------
# avg val loss per batch: 0.192273
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 34
# -----------------------------------------------
# current batch loss: 0.168232  [    0/30000]
# current batch loss: 0.161756  [12800/30000]
# current batch loss: 0.195487  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.195088
# -----------------------------------------------
# avg val loss per batch: 0.199531
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 35
# -----------------------------------------------
# current batch loss: 0.242358  [    0/30000]
# current batch loss: 0.202868  [12800/30000]
# current batch loss: 0.198023  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.186139
# -----------------------------------------------
# avg val loss per batch: 0.190371
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 36
# -----------------------------------------------
# current batch loss: 0.190678  [    0/30000]
# current batch loss: 0.152899  [12800/30000]
# current batch loss: 0.273072  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.168520
# -----------------------------------------------
# avg val loss per batch: 0.172807
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 37
# -----------------------------------------------
# current batch loss: 0.203595  [    0/30000]
# current batch loss: 0.168490  [12800/30000]
# current batch loss: 0.188037  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.174319
# -----------------------------------------------
# avg val loss per batch: 0.178289
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 38
# -----------------------------------------------
# current batch loss: 0.141507  [    0/30000]
# current batch loss: 0.103654  [12800/30000]
# current batch loss: 0.188660  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.156873
# -----------------------------------------------
# avg val loss per batch: 0.160801
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 39
# -----------------------------------------------
# current batch loss: 0.175904  [    0/30000]
# current batch loss: 0.174332  [12800/30000]
# current batch loss: 0.157815  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.155867
# -----------------------------------------------
# avg val loss per batch: 0.159715
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 40
# -----------------------------------------------
# current batch loss: 0.130518  [    0/30000]
# current batch loss: 0.142118  [12800/30000]
# current batch loss: 0.175082  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.157123
# -----------------------------------------------
# avg val loss per batch: 0.160282
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 41
# -----------------------------------------------
# current batch loss: 0.173084  [    0/30000]
# current batch loss: 0.104763  [12800/30000]
# current batch loss: 0.191547  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.141078
# -----------------------------------------------
# avg val loss per batch: 0.145614
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 42
# -----------------------------------------------
# current batch loss: 0.171782  [    0/30000]
# current batch loss: 0.161364  [12800/30000]
# current batch loss: 0.118548  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.133308
# -----------------------------------------------
# avg val loss per batch: 0.136806
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 43
# -----------------------------------------------
# current batch loss: 0.108293  [    0/30000]
# current batch loss: 0.135584  [12800/30000]
# current batch loss: 0.131656  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.136096
# -----------------------------------------------
# avg val loss per batch: 0.138606
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 44
# -----------------------------------------------
# current batch loss: 0.128035  [    0/30000]
# current batch loss: 0.124312  [12800/30000]
# current batch loss: 0.147849  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.138207
# -----------------------------------------------
# avg val loss per batch: 0.142787
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 45
# -----------------------------------------------
# current batch loss: 0.095509  [    0/30000]
# current batch loss: 0.170846  [12800/30000]
# current batch loss: 0.134626  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.117261
# -----------------------------------------------
# avg val loss per batch: 0.119571
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 46
# -----------------------------------------------
# current batch loss: 0.086649  [    0/30000]
# current batch loss: 0.100205  [12800/30000]
# current batch loss: 0.139633  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.114412
# -----------------------------------------------
# avg val loss per batch: 0.116743
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 47
# -----------------------------------------------
# current batch loss: 0.072607  [    0/30000]
# current batch loss: 0.145880  [12800/30000]
# current batch loss: 0.143312  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.110194
# -----------------------------------------------
# avg val loss per batch: 0.112904
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 48
# -----------------------------------------------
# current batch loss: 0.085704  [    0/30000]
# current batch loss: 0.100706  [12800/30000]
# current batch loss: 0.096748  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.111602
# -----------------------------------------------
# avg val loss per batch: 0.114411
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 49
# -----------------------------------------------
# current batch loss: 0.079873  [    0/30000]
# current batch loss: 0.121445  [12800/30000]
# current batch loss: 0.111222  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.103413
# -----------------------------------------------
# avg val loss per batch: 0.106969
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 50
# -----------------------------------------------
# current batch loss: 0.073304  [    0/30000]
# current batch loss: 0.100204  [12800/30000]
# current batch loss: 0.125306  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.121531
# -----------------------------------------------
# avg val loss per batch: 0.124688
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 51
# -----------------------------------------------
# current batch loss: 0.103373  [    0/30000]
# current batch loss: 0.127581  [12800/30000]
# current batch loss: 0.123773  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.104763
# -----------------------------------------------
# avg val loss per batch: 0.107334
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 52
# -----------------------------------------------
# current batch loss: 0.130597  [    0/30000]
# current batch loss: 0.067541  [12800/30000]
# current batch loss: 0.087275  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.111465
# -----------------------------------------------
# avg val loss per batch: 0.112741
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 53
# -----------------------------------------------
# current batch loss: 0.122703  [    0/30000]
# current batch loss: 0.144529  [12800/30000]
# current batch loss: 0.097372  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.098111
# -----------------------------------------------
# avg val loss per batch: 0.101501
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 54
# -----------------------------------------------
# current batch loss: 0.109391  [    0/30000]
# current batch loss: 0.083348  [12800/30000]
# current batch loss: 0.072301  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.103729
# -----------------------------------------------
# avg val loss per batch: 0.106776
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 55
# -----------------------------------------------
# current batch loss: 0.085688  [    0/30000]
# current batch loss: 0.117786  [12800/30000]
# current batch loss: 0.125561  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.121808
# -----------------------------------------------
# avg val loss per batch: 0.126265
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 56
# -----------------------------------------------
# current batch loss: 0.153849  [    0/30000]
# current batch loss: 0.088432  [12800/30000]
# current batch loss: 0.066282  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.096446
# -----------------------------------------------
# avg val loss per batch: 0.099452
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 57
# -----------------------------------------------
# current batch loss: 0.130855  [    0/30000]
# current batch loss: 0.097493  [12800/30000]
# current batch loss: 0.090817  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.092662
# -----------------------------------------------
# avg val loss per batch: 0.094795
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 58
# -----------------------------------------------
# current batch loss: 0.135623  [    0/30000]
# current batch loss: 0.109402  [12800/30000]
# current batch loss: 0.085480  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.091388
# -----------------------------------------------
# avg val loss per batch: 0.093040
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 59
# -----------------------------------------------
# current batch loss: 0.127085  [    0/30000]
# current batch loss: 0.090804  [12800/30000]
# current batch loss: 0.074709  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.093720
# -----------------------------------------------
# avg val loss per batch: 0.097400
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 60
# -----------------------------------------------
# current batch loss: 0.094198  [    0/30000]
# current batch loss: 0.110951  [12800/30000]
# current batch loss: 0.094983  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.087756
# -----------------------------------------------
# avg val loss per batch: 0.090995
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 61
# -----------------------------------------------
# current batch loss: 0.088999  [    0/30000]
# current batch loss: 0.100196  [12800/30000]
# current batch loss: 0.082673  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.092029
# -----------------------------------------------
# avg val loss per batch: 0.093991
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 62
# -----------------------------------------------
# current batch loss: 0.083902  [    0/30000]
# current batch loss: 0.091312  [12800/30000]
# current batch loss: 0.062188  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.090194
# -----------------------------------------------
# avg val loss per batch: 0.093618
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 63
# -----------------------------------------------
# current batch loss: 0.085696  [    0/30000]
# current batch loss: 0.050648  [12800/30000]
# current batch loss: 0.114723  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.083501
# -----------------------------------------------
# avg val loss per batch: 0.086778
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 64
# -----------------------------------------------
# current batch loss: 0.070565  [    0/30000]
# current batch loss: 0.090989  [12800/30000]
# current batch loss: 0.079204  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.081704
# -----------------------------------------------
# avg val loss per batch: 0.084867
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 65
# -----------------------------------------------
# current batch loss: 0.072143  [    0/30000]
# current batch loss: 0.088870  [12800/30000]
# current batch loss: 0.063881  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.091664
# -----------------------------------------------
# avg val loss per batch: 0.094137
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 66
# -----------------------------------------------
# current batch loss: 0.087789  [    0/30000]
# current batch loss: 0.057590  [12800/30000]
# current batch loss: 0.089728  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.084032
# -----------------------------------------------
# avg val loss per batch: 0.085795
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 67
# -----------------------------------------------
# current batch loss: 0.057693  [    0/30000]
# current batch loss: 0.066310  [12800/30000]
# current batch loss: 0.121126  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.082210
# -----------------------------------------------
# avg val loss per batch: 0.084673
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 68
# -----------------------------------------------
# current batch loss: 0.052727  [    0/30000]
# current batch loss: 0.080926  [12800/30000]
# current batch loss: 0.089442  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.079462
# -----------------------------------------------
# avg val loss per batch: 0.081914
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 69
# -----------------------------------------------
# current batch loss: 0.113025  [    0/30000]
# current batch loss: 0.074968  [12800/30000]
# current batch loss: 0.088130  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.091738
# -----------------------------------------------
# avg val loss per batch: 0.093297
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 70
# -----------------------------------------------
# current batch loss: 0.106800  [    0/30000]
# current batch loss: 0.073683  [12800/30000]
# current batch loss: 0.093678  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.075640
# -----------------------------------------------
# avg val loss per batch: 0.079006
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 71
# -----------------------------------------------
# current batch loss: 0.063560  [    0/30000]
# current batch loss: 0.073137  [12800/30000]
# current batch loss: 0.088578  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.082634
# -----------------------------------------------
# avg val loss per batch: 0.085572
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 72
# -----------------------------------------------
# current batch loss: 0.074600  [    0/30000]
# current batch loss: 0.066965  [12800/30000]
# current batch loss: 0.062109  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.071867
# -----------------------------------------------
# avg val loss per batch: 0.074129
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 73
# -----------------------------------------------
# current batch loss: 0.070200  [    0/30000]
# current batch loss: 0.046198  [12800/30000]
# current batch loss: 0.086498  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.085814
# -----------------------------------------------
# avg val loss per batch: 0.088943
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 74
# -----------------------------------------------
# current batch loss: 0.112114  [    0/30000]
# current batch loss: 0.078823  [12800/30000]
# current batch loss: 0.055758  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.086836
# -----------------------------------------------
# avg val loss per batch: 0.088322
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 75
# -----------------------------------------------
# current batch loss: 0.080479  [    0/30000]
# current batch loss: 0.081093  [12800/30000]
# current batch loss: 0.073393  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.069280
# -----------------------------------------------
# avg val loss per batch: 0.070806
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 76
# -----------------------------------------------
# current batch loss: 0.065765  [    0/30000]
# current batch loss: 0.069299  [12800/30000]
# current batch loss: 0.057732  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.070980
# -----------------------------------------------
# avg val loss per batch: 0.073131
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 77
# -----------------------------------------------
# current batch loss: 0.096718  [    0/30000]
# current batch loss: 0.100014  [12800/30000]
# current batch loss: 0.080648  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.072662
# -----------------------------------------------
# avg val loss per batch: 0.074254
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 78
# -----------------------------------------------
# current batch loss: 0.060778  [    0/30000]
# current batch loss: 0.060855  [12800/30000]
# current batch loss: 0.089985  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.068734
# -----------------------------------------------
# avg val loss per batch: 0.069548
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 79
# -----------------------------------------------
# current batch loss: 0.072888  [    0/30000]
# current batch loss: 0.046164  [12800/30000]
# current batch loss: 0.060097  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.077767
# -----------------------------------------------
# avg val loss per batch: 0.081118
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 80
# -----------------------------------------------
# current batch loss: 0.077848  [    0/30000]
# current batch loss: 0.052180  [12800/30000]
# current batch loss: 0.071078  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.071560
# -----------------------------------------------
# avg val loss per batch: 0.074811
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 81
# -----------------------------------------------
# current batch loss: 0.066361  [    0/30000]
# current batch loss: 0.097221  [12800/30000]
# current batch loss: 0.079876  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.068953
# -----------------------------------------------
# avg val loss per batch: 0.071384
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 82
# -----------------------------------------------
# current batch loss: 0.060775  [    0/30000]
# current batch loss: 0.063998  [12800/30000]
# current batch loss: 0.060650  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.070748
# -----------------------------------------------
# avg val loss per batch: 0.072499
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 83
# -----------------------------------------------
# current batch loss: 0.066586  [    0/30000]
# current batch loss: 0.056645  [12800/30000]
# current batch loss: 0.064365  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.064471
# -----------------------------------------------
# avg val loss per batch: 0.066722
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 84
# -----------------------------------------------
# current batch loss: 0.069115  [    0/30000]
# current batch loss: 0.064564  [12800/30000]
# current batch loss: 0.093048  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.062951
# -----------------------------------------------
# avg val loss per batch: 0.065162
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 85
# -----------------------------------------------
# current batch loss: 0.073727  [    0/30000]
# current batch loss: 0.058484  [12800/30000]
# current batch loss: 0.057115  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.073019
# -----------------------------------------------
# avg val loss per batch: 0.076186
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 86
# -----------------------------------------------
# current batch loss: 0.073668  [    0/30000]
# current batch loss: 0.069355  [12800/30000]
# current batch loss: 0.050253  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.061866
# -----------------------------------------------
# avg val loss per batch: 0.063266
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 87
# -----------------------------------------------
# current batch loss: 0.067737  [    0/30000]
# current batch loss: 0.083688  [12800/30000]
# current batch loss: 0.053914  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.068768
# -----------------------------------------------
# avg val loss per batch: 0.069856
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 88
# -----------------------------------------------
# current batch loss: 0.065201  [    0/30000]
# current batch loss: 0.072634  [12800/30000]
# current batch loss: 0.048315  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.066781
# -----------------------------------------------
# avg val loss per batch: 0.069533
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 89
# -----------------------------------------------
# current batch loss: 0.050522  [    0/30000]
# current batch loss: 0.082456  [12800/30000]
# current batch loss: 0.063986  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.062069
# -----------------------------------------------
# avg val loss per batch: 0.064359
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 90
# -----------------------------------------------
# current batch loss: 0.051737  [    0/30000]
# current batch loss: 0.064324  [12800/30000]
# current batch loss: 0.059497  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.081206
# -----------------------------------------------
# avg val loss per batch: 0.082405
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 91
# -----------------------------------------------
# current batch loss: 0.086764  [    0/30000]
# current batch loss: 0.038255  [12800/30000]
# current batch loss: 0.044916  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.060639
# -----------------------------------------------
# avg val loss per batch: 0.062543
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 92
# -----------------------------------------------
# current batch loss: 0.074893  [    0/30000]
# current batch loss: 0.069870  [12800/30000]
# current batch loss: 0.069378  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.068390
# -----------------------------------------------
# avg val loss per batch: 0.069587
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 93
# -----------------------------------------------
# current batch loss: 0.082360  [    0/30000]
# current batch loss: 0.054781  [12800/30000]
# current batch loss: 0.043500  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.073711
# -----------------------------------------------
# avg val loss per batch: 0.074285
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 94
# -----------------------------------------------
# current batch loss: 0.059089  [    0/30000]
# current batch loss: 0.062457  [12800/30000]
# current batch loss: 0.047545  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.076534
# -----------------------------------------------
# avg val loss per batch: 0.077719
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 95
# -----------------------------------------------
# current batch loss: 0.089330  [    0/30000]
# current batch loss: 0.095154  [12800/30000]
# current batch loss: 0.075901  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.060146
# -----------------------------------------------
# avg val loss per batch: 0.061945
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 96
# -----------------------------------------------
# current batch loss: 0.058670  [    0/30000]
# current batch loss: 0.080793  [12800/30000]
# current batch loss: 0.056391  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.058245
# -----------------------------------------------
# avg val loss per batch: 0.060332
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 97
# -----------------------------------------------
# current batch loss: 0.069133  [    0/30000]
# current batch loss: 0.058621  [12800/30000]
# current batch loss: 0.059189  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.057235
# -----------------------------------------------
# avg val loss per batch: 0.059067
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 98
# -----------------------------------------------
# current batch loss: 0.078133  [    0/30000]
# current batch loss: 0.053446  [12800/30000]
# current batch loss: 0.050169  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.062121
# -----------------------------------------------
# avg val loss per batch: 0.064219
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 99
# -----------------------------------------------
# current batch loss: 0.040076  [    0/30000]
# current batch loss: 0.059485  [12800/30000]
# current batch loss: 0.108020  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.063293
# -----------------------------------------------
# avg val loss per batch: 0.064551
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 100
# -----------------------------------------------
# current batch loss: 0.052587  [    0/30000]
# current batch loss: 0.053438  [12800/30000]
# current batch loss: 0.046557  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.063596
# -----------------------------------------------
# avg val loss per batch: 0.064747
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 101
# -----------------------------------------------
# current batch loss: 0.077566  [    0/30000]
# current batch loss: 0.075262  [12800/30000]
# current batch loss: 0.061785  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.057801
# -----------------------------------------------
# avg val loss per batch: 0.059314
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 102
# -----------------------------------------------
# current batch loss: 0.058383  [    0/30000]
# current batch loss: 0.082042  [12800/30000]
# current batch loss: 0.050352  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.059615
# -----------------------------------------------
# avg val loss per batch: 0.062096
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 103
# -----------------------------------------------
# current batch loss: 0.067446  [    0/30000]
# current batch loss: 0.058518  [12800/30000]
# current batch loss: 0.051454  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.056847
# -----------------------------------------------
# avg val loss per batch: 0.058514
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 104
# -----------------------------------------------
# current batch loss: 0.060433  [    0/30000]
# current batch loss: 0.077532  [12800/30000]
# current batch loss: 0.047548  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.056585
# -----------------------------------------------
# avg val loss per batch: 0.058533
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 105
# -----------------------------------------------
# current batch loss: 0.048754  [    0/30000]
# current batch loss: 0.041928  [12800/30000]
# current batch loss: 0.049859  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.052449
# -----------------------------------------------
# avg val loss per batch: 0.054414
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 106
# -----------------------------------------------
# current batch loss: 0.040566  [    0/30000]
# current batch loss: 0.074470  [12800/30000]
# current batch loss: 0.051001  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.069639
# -----------------------------------------------
# avg val loss per batch: 0.070862
# -----------------------------------------------
# |
# ...
# -----------------------------------------------
# avg trn loss per batch: 0.049485
# -----------------------------------------------
# avg val loss per batch: 0.051382
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 116
# -----------------------------------------------
# current batch loss: 0.041820  [    0/30000]
# current batch loss: 0.063828  [12800/30000]
# current batch loss: 0.036293  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.050770
# -----------------------------------------------
# avg val loss per batch: 0.052626
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 117
# -----------------------------------------------
# current batch loss: 0.053119  [    0/30000]
# current batch loss: 0.071759  [12800/30000]
# current batch loss: 0.062735  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.054392
# -----------------------------------------------
# avg val loss per batch: 0.056008
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 118
# -----------------------------------------------
# current batch loss: 0.058847  [    0/30000]
# current batch loss: 0.040011  [12800/30000]
# current batch loss: 0.075556  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049681
# -----------------------------------------------
# avg val loss per batch: 0.052186
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 119
# -----------------------------------------------
# current batch loss: 0.049664  [    0/30000]
# current batch loss: 0.039238  [12800/30000]
# current batch loss: 0.052897  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049547
# -----------------------------------------------
# avg val loss per batch: 0.052238
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 120
# -----------------------------------------------
# current batch loss: 0.050290  [    0/30000]
# current batch loss: 0.045910  [12800/30000]
# current batch loss: 0.039594  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.051960
# -----------------------------------------------
# avg val loss per batch: 0.055128
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 121
# -----------------------------------------------
# current batch loss: 0.072876  [    0/30000]
# current batch loss: 0.052133  [12800/30000]
# current batch loss: 0.055532  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.047203
# -----------------------------------------------
# avg val loss per batch: 0.049493
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 122
# -----------------------------------------------
# current batch loss: 0.038117  [    0/30000]
# current batch loss: 0.049866  [12800/30000]
# current batch loss: 0.034587  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.048090
# -----------------------------------------------
# avg val loss per batch: 0.050549
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 123
# -----------------------------------------------
# current batch loss: 0.046107  [    0/30000]
# current batch loss: 0.040583  [12800/30000]
# current batch loss: 0.052986  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.058070
# -----------------------------------------------
# avg val loss per batch: 0.059350
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 124
# -----------------------------------------------
# current batch loss: 0.065724  [    0/30000]
# current batch loss: 0.032433  [12800/30000]
# current batch loss: 0.042736  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049408
# -----------------------------------------------
# avg val loss per batch: 0.052274
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 125
# -----------------------------------------------
# current batch loss: 0.044448  [    0/30000]
# current batch loss: 0.038511  [12800/30000]
# current batch loss: 0.070581  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.048577
# -----------------------------------------------
# avg val loss per batch: 0.050741
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 126
# -----------------------------------------------
# current batch loss: 0.042496  [    0/30000]
# current batch loss: 0.051958  [12800/30000]
# current batch loss: 0.039289  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.047987
# -----------------------------------------------
# avg val loss per batch: 0.049865
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 127
# -----------------------------------------------
# current batch loss: 0.048737  [    0/30000]
# current batch loss: 0.041112  [12800/30000]
# current batch loss: 0.083805  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.044388
# -----------------------------------------------
# avg val loss per batch: 0.046388
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 128
# -----------------------------------------------
# current batch loss: 0.045819  [    0/30000]
# current batch loss: 0.049870  [12800/30000]
# current batch loss: 0.054295  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.044682
# -----------------------------------------------
# avg val loss per batch: 0.047142
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 129
# -----------------------------------------------
# current batch loss: 0.052495  [    0/30000]
# current batch loss: 0.049308  [12800/30000]
# current batch loss: 0.056310  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049440
# -----------------------------------------------
# avg val loss per batch: 0.051180
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 130
# -----------------------------------------------
# current batch loss: 0.062901  [    0/30000]
# current batch loss: 0.043437  [12800/30000]
# current batch loss: 0.047986  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.045483
# -----------------------------------------------
# avg val loss per batch: 0.048301
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 131
# -----------------------------------------------
# current batch loss: 0.043667  [    0/30000]
# current batch loss: 0.091907  [12800/30000]
# current batch loss: 0.046710  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.046423
# -----------------------------------------------
# avg val loss per batch: 0.048383
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 132
# -----------------------------------------------
# current batch loss: 0.049075  [    0/30000]
# current batch loss: 0.048195  [12800/30000]
# current batch loss: 0.034928  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.044904
# -----------------------------------------------
# avg val loss per batch: 0.046069
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 133
# -----------------------------------------------
# current batch loss: 0.063128  [    0/30000]
# current batch loss: 0.045589  [12800/30000]
# current batch loss: 0.041752  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049968
# -----------------------------------------------
# avg val loss per batch: 0.051484
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 134
# -----------------------------------------------
# current batch loss: 0.055926  [    0/30000]
# current batch loss: 0.040870  [12800/30000]
# current batch loss: 0.065214  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.067896
# -----------------------------------------------
# avg val loss per batch: 0.070896
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 135
# -----------------------------------------------
# current batch loss: 0.056360  [    0/30000]
# current batch loss: 0.046470  [12800/30000]
# current batch loss: 0.055786  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.050798
# -----------------------------------------------
# avg val loss per batch: 0.053327
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 136
# -----------------------------------------------
# current batch loss: 0.029438  [    0/30000]
# current batch loss: 0.050958  [12800/30000]
# current batch loss: 0.037388  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.041631
# -----------------------------------------------
# avg val loss per batch: 0.043678
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 137
# -----------------------------------------------
# current batch loss: 0.043656  [    0/30000]
# current batch loss: 0.057235  [12800/30000]
# current batch loss: 0.061627  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.051722
# -----------------------------------------------
# avg val loss per batch: 0.055008
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 138
# -----------------------------------------------
# current batch loss: 0.041062  [    0/30000]
# current batch loss: 0.037925  [12800/30000]
# current batch loss: 0.057393  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.040258
# -----------------------------------------------
# avg val loss per batch: 0.042260
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 139
# -----------------------------------------------
# current batch loss: 0.048158  [    0/30000]
# current batch loss: 0.048121  [12800/30000]
# current batch loss: 0.062122  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.042832
# -----------------------------------------------
# avg val loss per batch: 0.044824
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 140
# -----------------------------------------------
# current batch loss: 0.058264  [    0/30000]
# current batch loss: 0.037653  [12800/30000]
# current batch loss: 0.044181  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.041233
# -----------------------------------------------
# avg val loss per batch: 0.043338
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 141
# -----------------------------------------------
# current batch loss: 0.045695  [    0/30000]
# current batch loss: 0.035864  [12800/30000]
# current batch loss: 0.039776  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.042258
# -----------------------------------------------
# avg val loss per batch: 0.043921
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 142
# -----------------------------------------------
# current batch loss: 0.045629  [    0/30000]
# current batch loss: 0.041413  [12800/30000]
# current batch loss: 0.036218  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.044102
# -----------------------------------------------
# avg val loss per batch: 0.045694
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 143
# -----------------------------------------------
# current batch loss: 0.038754  [    0/30000]
# current batch loss: 0.043569  [12800/30000]
# current batch loss: 0.035943  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.040003
# -----------------------------------------------
# avg val loss per batch: 0.041755
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 144
# -----------------------------------------------
# current batch loss: 0.030057  [    0/30000]
# current batch loss: 0.049116  [12800/30000]
# current batch loss: 0.046842  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.040754
# -----------------------------------------------
# avg val loss per batch: 0.042466
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 145
# -----------------------------------------------
# current batch loss: 0.043799  [    0/30000]
# current batch loss: 0.041503  [12800/30000]
# current batch loss: 0.032980  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.042568
# -----------------------------------------------
# avg val loss per batch: 0.044989
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 146
# -----------------------------------------------
# current batch loss: 0.053623  [    0/30000]
# current batch loss: 0.062789  [12800/30000]
# current batch loss: 0.043750  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.037651
# -----------------------------------------------
# avg val loss per batch: 0.039607
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 147
# -----------------------------------------------
# current batch loss: 0.041367  [    0/30000]
# current batch loss: 0.058034  [12800/30000]
# current batch loss: 0.039100  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.049586
# -----------------------------------------------
# avg val loss per batch: 0.052021
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 148
# -----------------------------------------------
# current batch loss: 0.034319  [    0/30000]
# current batch loss: 0.055739  [12800/30000]
# current batch loss: 0.035737  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.041100
# -----------------------------------------------
# avg val loss per batch: 0.043061
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 149
# -----------------------------------------------
# current batch loss: 0.039072  [    0/30000]
# current batch loss: 0.039651  [12800/30000]
# current batch loss: 0.030986  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.037669
# -----------------------------------------------
# avg val loss per batch: 0.039918
# -----------------------------------------------
# |
# -----------------------------------------------
# Epoch 150
# -----------------------------------------------
# current batch loss: 0.050646  [    0/30000]
# current batch loss: 0.035787  [12800/30000]
# current batch loss: 0.039627  [25600/30000]
# -----------------------------------------------
# avg trn loss per batch: 0.039719
# -----------------------------------------------
# avg val loss per batch: 0.041782
# -----------------------------------------------
# |
# Done!

# %% [markdown]
# ## Plot the train and validation losses as a function of the epochs

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( trn_losses, label="train loss", color=c1 )
axs.plot( val_losses, label="val   loss", color=c2 )

axs.set_yscale('log')

axs.set_xlabel( "epoch", fontproperties=axislabelfont )
axs.set_ylabel( "MSE", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %% [markdown]
# We can see that both the train and validation losses are being reduced during training, the model is fitting well!
#
# We haven't used the test data here.  The test data becomes useful if our neural network overfits the training data, and we want to stop training the network early.  In this case we use the validation data to decide at which epoch to stop training, based on some early stopping condition.  For example, if the validation loss does not improve for 10 epochs, we might decide to stop training.  If we have saved the network at certain epochs during training, we would then select the network with the smallest validation loss to use.  The test data is then the final dataset we test on, since it was not used during training or in the early stopping procedure.

# %% [markdown]
# ## Study the results

# %% [markdown]
# Now we want to get some visualisation of how well our amplitude regression has worked.
#
# The simplest thing we can do is to pass our data through the neural network to get a predicted amplitude for each event, then histogram this and compare it to the histogram of the true amplitudes.

# %%
def get_amps( model, dataloader ):
    
    amps = []

    # we don't need gradients here since we only use the forward pass
    with torch.no_grad():
        for X, y in dataloader:
            amps += [ a.item() for a in model( X.to(device) ) ]

    return amps

# %%
pred_trn_ampls = get_amps( model, trn_dataloader )
pred_val_ampls = get_amps( model, val_dataloader )

# %% [markdown]
# First for the training data:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

(n1, bins, patches1 ) = axs.hist( trn_ampl, histtype='stepfilled', fill=None, edgecolor=c1, label="train data", ls="--" )
(n2, bins, patches2 ) = axs.hist( pred_trn_ampls, histtype='stepfilled', fill=None, edgecolor=c2, label="train preds", bins=bins )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %%
matplotlib.rcParams["text.usetex"]  = True

# %% [markdown]
# We can also try to visualise the error on the predicted amplitudes by plotting $\text{abs}\left((A_{\text{true}}-A_{\text{pred}})/A_{\text{true}} \right)$.

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( np.abs((n1-n2)/n1), color=c1 )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "Error", fontproperties=axislabelfont )

xticks = np.round( axs.get_xticks(), 2 )
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = np.round( axs.get_yticks(), 2 )
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# The error is lowest in the regions where there is more training data, this is expected.  The more data the network has to learn from, the better it can learn to predict the correct amplitude.

# %% [markdown]
# And then for the validation data:

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

(n1, bins, patches1) = axs.hist( val_ampl, histtype='stepfilled', fill=None, edgecolor=c1, label="val data", ls="--" )
(n2, bins, patches2) = axs.hist( pred_val_ampls, histtype='stepfilled', fill=None, edgecolor=c2, label="val preds", bins=bins )

axs.set_yscale( 'log' )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "number of events", fontproperties=axislabelfont )

xticks = axs.get_xticks()
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = axs.get_yticks()
axs.set_yticklabels( yticks, fontproperties=tickfont )

axs.legend( loc='best', prop=tickfont )

fig.tight_layout()

# %%
fig, axs = plt.subplots( 1, 1, figsize=(7,5) )

c1 = 'tab:red'
c2 = 'tab:green'

axs.plot( np.abs((n1-n2)/n1), color=c1 )

axs.set_xlabel( "log( train amplitudes )", fontproperties=axislabelfont )
axs.set_ylabel( "Error", fontproperties=axislabelfont )

xticks = np.round( axs.get_xticks(), 2 )
axs.set_xticklabels( xticks, fontproperties=tickfont )

yticks = np.round( axs.get_yticks(), 2 )
axs.set_yticklabels( yticks, fontproperties=tickfont )

fig.tight_layout()

# %% [markdown]
# ## Improvements?

# %% [markdown]
# General ways to improve ML analyses:
# - more data
# - larger network
# - longer training
# - better optimization

# %% [markdown]
# What about improvements that could be made specific to this physics example?

# %% [markdown]
# We could take advantage of the physical symmetries in the problem:
# - permutation invariance of:
#     - initial gluons
#     - outgoing photons
# - azimuthal symmetry of the amplitude due to alignment of initial gluons
